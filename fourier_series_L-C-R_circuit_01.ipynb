# %%
import matplotlib.pyplot as plt

# Frequency and peak amplitude values
frequency = [
  1000,
2000,
3000,
4000,
5000,
6000,
7000,
8000,
9000,
10000,
11000,
12000,
13000,
14000,
14100,
14200,
14225,
14250,
14275,
14285,
14295,
14300,
14400,
14500,
14600,
14700,
14800,
14900,
15000,
16000,
17000,
18000,
]

q = [
    1.02,
1.025125628,
1.035175879,
1.095477387,
1.145728643,
1.212121212,
1.331658291,
1.449494949,
1.621212121,
1.914141414,
2.360406091,
3.14213198,
4.974747475,
14.11557789,
17.53768844,
23.12060302,
25.07035176,
27.54040404,
30.2361809,
31.65656566,
32.88442211,
33.585,
57.34673367,
76.26984127,
49.37765957,
30.96875,
22.03125,
16.84455959,
13.52061856,
4.403061224,
2.584615385,
1.794871795,
]

# Plotting the graph
plt.figure(figsize=(10, 5))
plt.plot(frequency, q, marker='o', linestyle='-')
plt.title('Frequency vs Q')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Peak Amp (Vʙ/Vᴀ)')
plt.grid(True)
plt.savefig("plot_1.png", dpi=500)
