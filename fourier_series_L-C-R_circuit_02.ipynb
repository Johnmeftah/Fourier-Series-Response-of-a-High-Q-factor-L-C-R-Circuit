# %%
import matplotlib.pyplot as plt

# Frequency and peak amplitude values
frequency = [
 14500,
7250,
4833.333333,
3625,
2900,
2416.666667,
2071.428571,
1812.5,
1611.111111,
1450,
]

An_A1= [
1,
0.022099142,
0.383273331,
0.022099142,
0.244918305,
0.021988369,
0.182885627,
0.022376073,
0.147992246,
0.022486846,
]

# Plotting the graph
plt.figure(figsize=(10, 5))
plt.plot(frequency, An_A1, marker='o', linestyle='-')
plt.title('Aₙ/A₁ vs Frequency')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Aₙ/A₁')
plt.grid(True)
plt.savefig("plot_2.png", dpi=500)
